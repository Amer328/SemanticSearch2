# %% [markdown]
# <a href="https://colab.research.google.com/github/Amer328/SemanticSearch2/blob/main/YtubeTranscript.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install youtube_transcript_api
from youtube_transcript_api import YouTubeTranscriptApi
import re
# Out:
# Requirement already satisfied: youtube_transcript_api in /usr/local/lib/python3.11/dist-packages (1.0.3)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from youtube_transcript_api) (0.7.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from youtube_transcript_api) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->youtube_transcript_api) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->youtube_transcript_api) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->youtube_transcript_api) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->youtube_transcript_api) (2025.1.31)

# %%
def extract_youtube_transcript(video_url):
    """
    Extracts the transcript from a given YouTube video URL.

    Args:
    video_url (str): The URL of the YouTube video.

    Returns:
    str: The formatted transcript of the video, or an error message if the transcript is not available.
    """
    # Extract the video ID from the URL
    video_id = extract_video_id(video_url)

    if not video_id:
        return "Error: Invalid YouTube URL or unable to extract video ID."

    try:
        # Fetch the transcript
        transcript = YouTubeTranscriptApi.get_transcript(video_id)

        # Format the transcript
        formatted_transcript = format_transcript(transcript)

        return formatted_transcript

    except Exception as e:
        return f"Error: Unable to fetch transcript. {str(e)}"

# %%
def extract_video_id(url):
    """
    Extracts the video ID from a YouTube URL.

    Args:
    url (str): The YouTube video URL.

    Returns:
    str: The extracted video ID, or None if not found.
    """
    # Regular expression to match YouTube video URLs
    pattern = r'(?:v=|v\/|embed\/|youtu\.be\/|\/v\/|\/e\/|watch\?v=|watch\?feature=player_embedded&v=|watch\?feature=player_detailpage&v=|watch\?feature=player_profilepage&v=)([A-Za-z0-9_-]+)'

    match = re.search(pattern, url)
    if match:
        return match.group(1)
    return None

def format_transcript(transcript):
    """
    Formats the raw transcript data into a readable format.

    Args:
    transcript (list): The raw transcript data.

    Returns:
    str: The formatted transcript.
    """
    formatted = []
    for entry in transcript:
        start_time = entry['start']
        duration = entry['duration']
        text = entry['text']

        # Format the time as minutes:seconds
        minutes, seconds = divmod(int(start_time), 60)
        time_str = f"{minutes:02d}:{seconds:02d}"

        formatted.append(f"[{time_str}] {text}")

    return "\n".join(formatted)

# %%
# Example usage
video_url = "https://www.youtube.com/watch?v=Tbi6Mdp9rQo"
result = extract_youtube_transcript(video_url)
print(result)
# Out:
# [00:00] it is the latest chapter heading in a
# [00:03] long saga and I'm afraid this is going
# [00:05] to go on for quite some time quite a
# [00:07] roller coaster here um the latest of
# [00:09] course is that Donald Trump wants to
# [00:10] impose extra tariffs on car imports why
# [00:14] well it comes back to this chart a chart
# [00:16] that you really will not like at all
# [00:18] this is showing you US exports of cars
# [00:20] around the world going back to the 1960s
# [00:23] and the key thing is comparing exports
# [00:25] with imports look at that line has
# [00:27] imports into the US of cars and of
# [00:30] course the difference between that one
# [00:31] line and the other one is the trade
# [00:33] deficit so the US sucking in many more
# [00:35] cars from overseas than it makes uh or
# [00:37] sends out itself and that's what Donald
# [00:39] Trump really wants to try to remedy and
# [00:41] he wants to do it through tariffs
# [00:42] raising the question what are the level
# [00:44] of tariffs going to be and I'm afraid
# [00:46] there's no simple answer here because
# [00:47] there's quite a lot of different
# [00:48] categories we can talk about here first
# [00:50] of all so simplest there's cars and
# [00:53] right now the tariff on cars it's called
# [00:54] the most favored nation tariff uh MFN is
# [00:57] 2.5% so really quite low on cars and of
# [01:00] course on top of that you're going to
# [01:01] have that 25% so that goes up to just
# [01:03] over 25% but it's not just the finished
# [01:06] cars it's also the components in those
# [01:08] cars that then get kind of worked out
# [01:10] and you have to pay a tariff on just how
# [01:12] much of the stuff isn't made in America
# [01:14] it's going to be very difficult to work
# [01:16] that out um but nonetheless you're
# [01:18] talking about 25% there so cars
# [01:20] components light trucks are already
# [01:23] actually tariffed not at 2.5% but at
# [01:26] 25% it's the chicken tax basically back
# [01:29] in the 1960s Europe wasn't importing as
# [01:32] much they were had kind of import blocks
# [01:34] on chickens factory farm chickens from
# [01:36] the US and in retaliation Lyndon Johnson
# [01:38] said "Right we're going to put tariffs
# [01:40] on your trucks." Uh the chicken tax
# [01:42] still there still in place and on top of
# [01:43] the chicken tax now comes another 25%
# [01:46] this Donald Trump uh tariff but think
# [01:50] about those who are making Chinese
# [01:51] electric vehicles the picture for them
# [01:53] is is kind of extraordinary you've
# [01:54] probably never seen anything like this
# [01:55] so they already have to pay there's the
# [01:58] 2.5% but they on top of that you've got
# [02:00] 100% tariffs uh from Joe Biden he put
# [02:03] those extra tariffs on Chinese EVs then
# [02:05] you've got another 20% that Donald Trump
# [02:07] put on top of that then potentially 25%
# [02:11] tariffs on anyone who's importing oil
# [02:13] crude oil from Venezuela that's that's
# [02:15] one of the latest tariffs and now you've
# [02:16] got another 25% on top of that i mean
# [02:20] it's extraordinary really tot it up and
# [02:22] you're talking about it's over
# [02:24] 170% tariffs amazing really uh and then
# [02:27] you've got light trucks at 50% and then
# [02:29] components uh as well um of course this
# [02:33] is going to affect many countries
# [02:34] because when it comes to imports when it
# [02:36] comes to manufacturing there is nothing
# [02:38] more iconic or important than car
# [02:40] manufacturing it goes it's really at the
# [02:42] heart of most countries all particularly
# [02:43] all of these countries manufacturing
# [02:45] sectors and it's kind of the usual
# [02:48] suspect so Mexico there uh Japan Canada
# [02:51] um these are all going to face big
# [02:53] tariffs 25% uh tariffs potentially uh
# [02:57] and just look there the UK people don't
# [02:59] think of the UK as being a big car
# [03:00] manufacturer well it's nowhere near as
# [03:02] big as some of the others but still the
# [03:03] sixth biggest importer of cars into the
# [03:06] US mostly highv value cars so you're
# [03:08] talking about JLI you're talking about
# [03:10] luxury vehicles
# [03:11] But it really does add up and actually
# [03:14] when you look at the UK and where the UK
# [03:16] sends its cars to there is again no
# [03:19] single country that is as important to
# [03:21] the UK car industry for exports as the
# [03:24] United States this is a really big deal
# [03:26] for the UK car industry as well as the
# [03:29] rest now I said earlier it's not just
# [03:32] cars it's also the components that go
# [03:34] inside the cars and this is where things
# [03:36] get kind of complicated but also quite
# [03:38] interesting so what I'm going to do is
# [03:40] we're going to kind of dissect and think
# [03:41] about America's most popular car the
# [03:44] Ford F-150 uh pickup truck and just how
# [03:47] much of the bits and pieces in there
# [03:49] actually come from America cuz you might
# [03:52] have thought this is entirely made in
# [03:54] America and to some extent it is but
# [03:56] inside it the components they come from
# [03:59] various other places so what we've got
# [04:01] here is a chart showing you the
# [04:03] percentage of the value of that car that
# [04:06] is actually made in America and a few
# [04:08] years ago back in the kind of early
# [04:09] 2010s it was up at around you were
# [04:12] talking about kind of what is it 75%
# [04:14] there but a number of the factories
# [04:16] making things like engines and so on
# [04:18] have shut down since then particularly
# [04:19] around Michigan with the upshot uh that
# [04:22] now you're talking about only 45% of it
# [04:24] being US and Canadian and also it's that
# [04:26] question of you know how much of the
# [04:28] Canadian uh manufacturing uh is going to
# [04:30] be charged uh is going to face tariffs
# [04:32] so even for iconic American cars like
# [04:35] this potentially tariffs and that pushes
# [04:39] up the price same thing again for
# [04:41] America's most popular electric vehicle
# [04:43] the Tesla Model Y now here more of this
# [04:46] car is made in the US but say for
# [04:49] instance consider the motor that's a US
# [04:52] uh production you've got the battery
# [04:53] pack that's put together in Nevada uh at
# [04:56] the Gigafactory there it's a Japanese
# [04:58] company actually Panasonic that make the
# [04:59] batteries but nonetheless it's America
# [05:01] although some of the chemicals are
# [05:02] coming from uh from elsewhere overall
# [05:05] 70% US Canadian content uh in the Model
# [05:08] Y um whereas you've got about 25% um
# [05:12] Mexican components and then there's
# [05:13] another 5% or so from elsewhere like I
# [05:15] say you've got those chemicals going
# [05:16] into the battery um all of this raises a
# [05:20] question okay so for American car makers
# [05:23] you're probably wondering who is most
# [05:25] hit by this uh and what we can do is we
# [05:27] can draw up a list of of the companies
# [05:29] from the most vulnerable and the most
# [05:31] vulnerable are the companies that aren't
# [05:33] making as many you know that a smaller
# [05:34] proportion of their cars is actually
# [05:36] made in America uh to to the least
# [05:39] vulnerable so the higher the this line
# [05:40] is and the red one there is the least
# [05:42] vulnerable who do you think is the least
# [05:44] vulnerable of all the car
# [05:47] manufacturers guess what it's Elon
# [05:49] Musk's company coincidence or not you be
# [05:52] the judge but if you look at what's
# [05:54] happened to share prices of car makers
# [05:56] well this is showing you share prices of
# [05:57] car makers over the past uh year or so
# [06:00] they've got Stalantis Toyota GM uh some
# [06:03] of them down quite a lot look at
# [06:04] Stalantis down 59 uh% uh but so far
# [06:08] there is one winner it's I mean it's
# [06:09] been a roller coaster for Tesla and a
# [06:11] lot of these shares are down a wee bit
# [06:12] in the last couple of days
# [06:14] unsurprisingly given what we've heard
# [06:15] about these tariffs but Tesla up by 51%
# [06:18] over that period like down from that
# [06:20] period there just underlining how much
# [06:22] of a roller coaster this is and I'm
# [06:24] afraid this roller coaster has only just
# [06:27] begun and there is going to be much more
# [06:28] to come
